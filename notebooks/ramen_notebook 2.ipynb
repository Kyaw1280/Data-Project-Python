# %% [markdown]
# ## Ramen Ratings Data Analysis

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### Question & Hypotheses
#
# 1. Which country produces the highest rated ramen?
#     - Hypothesis: Japanese ramen brands generally receive higher ratings than brands from other countries
# 2. Do the ratings scores vary widely in this dataset?
# 3. Who are the most and least reviewed brands?
#     - Hypothesis: A few popular brands are rated far more than others
# 4. Which brands most consistently receive high average ratings?
# 5. Does the style of ramen (e.g. cup, bowl, pack) affect its rating?
#     - Hypothesis: Ramen served in unusual styles like bottle or can will have lower ratings and traditional styles like box will have the highest ratings

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
df = pd.read_csv('../data/Top_Ramen_Ratings.csv')

df.head()
# Out:
#    Review #            Brand                                Variety Style  \
# 0      4120              MIT               Shallot Sauce Dry Noodle  Pack
# 1      4119  Sapporo Ichiban  Tonkotsu Ramen Japanese Style Noodles  Bowl
# 2      4118         Binh Tay                                Mi Kiwi  Bowl
# 3      4117  Charming Couple     Biang Biang Scallion Chicken Sauce  Pack
# 4      4116             immi       Tom Yum Shrimp Flavor Ramen Soup  Pack
#
#          Country Stars   T
# 0         Taiwan     3 NaN
# 1  United States   4.5 NaN
# 2        Vietnam     3 NaN
# 3         Taiwan   4.5 NaN
# 4  United States  2.75 NaN

# %%
df.shape
# Out:
# (4120, 7)

# %%
df.tail()
# Out:
#       Review #     Brand                                            Variety  \
# 4115         5     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 4116         4   Wai Wai                     Oriental Style Instant Noodles
# 4117         3   Wai Wai                                     Tom Yum Shrimp
# 4118         2   Wai Wai                               Tom Yum Chili Flavor
# 4119         1  Westbrae                                         Miso Ramen
#
#      Style        Country Stars   T
# 4115  Bowl        Vietnam   3.5 NaN
# 4116  Pack       Thailand     1 NaN
# 4117  Pack       Thailand     2 NaN
# 4118  Pack       Thailand     2 NaN
# 4119  Pack  United States   0.5 NaN

# %%
df.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          0
# Country        0
# Stars          0
# T           4120
# dtype: int64

# %%
# Option 1
#df.drop('T', axis='columns', inplace=True)

# Option 2
# df.drop('T', axis=1, inplace=True)

df.head()
# Out:
#    Review #            Brand                                Variety Style  \
# 0      4120              MIT               Shallot Sauce Dry Noodle  Pack
# 1      4119  Sapporo Ichiban  Tonkotsu Ramen Japanese Style Noodles  Bowl
# 2      4118         Binh Tay                                Mi Kiwi  Bowl
# 3      4117  Charming Couple     Biang Biang Scallion Chicken Sauce  Pack
# 4      4116             immi       Tom Yum Shrimp Flavor Ramen Soup  Pack
#
#          Country Stars   T
# 0         Taiwan     3 NaN
# 1  United States   4.5 NaN
# 2        Vietnam     3 NaN
# 3         Taiwan   4.5 NaN
# 4  United States  2.75 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4120 entries, 0 to 4119
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  4120 non-null   int64
#  1   Brand     4120 non-null   object
#  2   Variety   4120 non-null   object
#  3   Style     4120 non-null   object
#  4   Country   4120 non-null   object
#  5   Stars     4120 non-null   object
#  6   T         0 non-null      float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 225.4+ KB

# %%
df['Stars'].value_counts()
# Out:
# Stars
# 5          775
# 3.5        607
# 3.75       581
# 4          489
# 4.5        282
# 3.25       236
# 4.25       223
# 3          191
# 2.75       118
# 2          104
# 4.75       103
# 2.5        102
# 1.5         54
# 0           44
# 1           44
# 1.75        33
# 2.25        32
# 0.5         24
# 0.25        21
# 1.25        16
# NR           3
# Unrated      3
# 4.25/5       2
# 1.1          2
# 0.75         2
# 3.1          2
# 2.9          2
# 2.8          2
# 4.125        2
# 4.5/5        1
# 5/5          1
# 4/4          1
# 3.5/2.5      1
# NS           1
# 2.1          1
# 3.50         1
# 5/2.5        1
# 5/4          1
# 3.125        1
# 0.9          1
# 2.125        1
# 0.1          1
# 3.7          1
# 3.4          1
# 3.6          1
# 2.85         1
# 2.3          1
# 3.2          1
# 3.65         1
# 1.8          1
# Name: count, dtype: int64

# %%
no_stars_msk = (df['Stars'] == 'NR') | (df['Stars'] == 'Unrated') | (df['Stars'] == 'NS')
df_no_rating_rows = df[no_stars_msk]
df_no_rating_rows
# Out:
#       Review #          Brand                                Variety Style  \
# 687       3433     Base Foods                           Base Noodles  Pack
# 970       3150       Hakubaku                             Baby Somen  Pack
# 971       3149       Hakubaku                              Baby Udon  Pack
# 1479      2641      Nanoblock                            Ramen Bokki  Pack
# 1572      2548         Ottogi  Plain Instant Noodle No Soup Included  Pack
# 1662      2458  Samyang Foods                             Sari Ramen  Pack
# 2533      1587       Mi E-Zee                          Plain Noodles  Pack
#
#             Country    Stars   T
# 687   United States       NS NaN
# 970           Japan       NR NaN
# 971           Japan       NR NaN
# 1479          Japan       NR NaN
# 1572    South Korea  Unrated NaN
# 1662    South Korea  Unrated NaN
# 2533       Malaysia  Unrated NaN

# %%
df = df[~no_stars_msk]

df.shape
# Out:
# (4113, 7)

# %%
df['Stars'] = df['Stars'].str.replace(r'/.*', '', regex=True)

# %%
df['Stars'].value_counts()
# Out:
# Stars
# 5        778
# 3.5      608
# 3.75     581
# 4        490
# 4.5      283
# 3.25     236
# 4.25     225
# 3        191
# 2.75     118
# 2        104
# 4.75     103
# 2.5      102
# 1.5       54
# 0         44
# 1         44
# 1.75      33
# 2.25      32
# 0.5       24
# 0.25      21
# 1.25      16
# 0.75       2
# 1.1        2
# 4.125      2
# 3.1        2
# 2.8        2
# 2.9        2
# 2.1        1
# 3.50       1
# 3.125      1
# 0.9        1
# 2.125      1
# 0.1        1
# 3.7        1
# 3.4        1
# 3.6        1
# 2.85       1
# 2.3        1
# 3.2        1
# 3.65       1
# 1.8        1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4113 entries, 0 to 4119
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  4113 non-null   int64
#  1   Brand     4113 non-null   object
#  2   Variety   4113 non-null   object
#  3   Style     4113 non-null   object
#  4   Country   4113 non-null   object
#  5   Stars     4113 non-null   object
#  6   T         0 non-null      float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 257.1+ KB

# %%
df['Stars'] = pd.to_numeric(df['Stars'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4113 entries, 0 to 4119
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  4113 non-null   int64
#  1   Brand     4113 non-null   object
#  2   Variety   4113 non-null   object
#  3   Style     4113 non-null   object
#  4   Country   4113 non-null   object
#  5   Stars     4113 non-null   float64
#  6   T         0 non-null      float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 257.1+ KB

# %%
df = df[(df['Stars'] >= 0) & (df['Stars'] <= 5)]
df.shape
# Out:
# (4113, 7)

# %%
df.head()
# Out:
#    Review #            Brand                                Variety Style  \
# 0      4120              MIT               Shallot Sauce Dry Noodle  Pack
# 1      4119  Sapporo Ichiban  Tonkotsu Ramen Japanese Style Noodles  Bowl
# 2      4118         Binh Tay                                Mi Kiwi  Bowl
# 3      4117  Charming Couple     Biang Biang Scallion Chicken Sauce  Pack
# 4      4116             immi       Tom Yum Shrimp Flavor Ramen Soup  Pack
#
#          Country  Stars   T
# 0         Taiwan   3.00 NaN
# 1  United States   4.50 NaN
# 2        Vietnam   3.00 NaN
# 3         Taiwan   4.50 NaN
# 4  United States   2.75 NaN

# %%
unique_countries_sorted = sorted(df['Country'].unique())
unique_countries_sorted
# Out:
# ['Australia',
#  'Bangladesh',
#  'Brazil',
#  'Cambodia',
#  'Canada',
#  'China',
#  'Colombia',
#  'Dubai',
#  'Estonia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Germany',
#  'Ghana',
#  'Holland',
#  'Hong Kong',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Malaysia',
#  'Mexico',
#  'Myanmar',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'Pakistan',
#  'Peru',
#  'Philippines',
#  'Phlippines',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Russian Federation',
#  'Sarawak',
#  'Serbia',
#  'Singapore',
#  'Souh Korea',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Taiwan',
#  'Thailand',
#  'UK',
#  'USA',
#  'Ukraine',
#  'United Kingdom',
#  'United States',
#  'Vietnam']

# %%
countries = {
    'Holland': 'Netherlands',
    'Phlippines': 'Philippines',
    'Russian Federation': 'Russia',
    'Souh Korea': 'South Korea',
    'Sarawak': 'Malaysia',
    'UK': 'United Kingdom',
    'USA': 'United States'
}

df['Country'] = df['Country'].replace(countries)

# %%
df['Country'].value_counts()
# Out:
# Country
# Japan             797
# United States     570
# South Korea       428
# Taiwan            405
# China             286
# Thailand          233
# Malaysia          230
# Hong Kong         205
# Indonesia         175
# Singapore         144
# Vietnam           129
# United Kingdom     77
# Canada             56
# Philippines        54
# India              46
# Germany            38
# Mexico             32
# Australia          25
# Brazil             24
# Netherlands        20
# Nepal              14
# Myanmar            14
# Pakistan           13
# Bangladesh         12
# Hungary             9
# Russia              7
# France              6
# Poland              6
# Colombia            6
# Serbia              5
# Cambodia            5
# Ireland             4
# Peru                4
# Italy               4
# Fiji                4
# Finland             3
# Spain               3
# Israel              3
# Dubai               3
# Sweden              3
# Ukraine             3
# Ghana               2
# Estonia             2
# Nigeria             2
# Portugal            1
# New Zealand         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Review #            Brand                                Variety Style  \
# 0      4120              MIT               Shallot Sauce Dry Noodle  Pack
# 1      4119  Sapporo Ichiban  Tonkotsu Ramen Japanese Style Noodles  Bowl
# 2      4118         Binh Tay                                Mi Kiwi  Bowl
# 3      4117  Charming Couple     Biang Biang Scallion Chicken Sauce  Pack
# 4      4116             immi       Tom Yum Shrimp Flavor Ramen Soup  Pack
#
#          Country  Stars   T
# 0         Taiwan   3.00 NaN
# 1  United States   4.50 NaN
# 2        Vietnam   3.00 NaN
# 3         Taiwan   4.50 NaN
# 4  United States   2.75 NaN

# %%
unique_brands_sorted = sorted(df['Brand'].unique())
unique_brands_sorted
# Out:
# ['1 To 3 Noodles',
#  '7 Select',
#  '7 Select/Nissin',
#  '7-Eleven / Nissin',
#  'A-One',
#  'A-Sha',
#  'A-Sha Dry Noodle',
#  'A1',
#  'ABC',
#  'ABC President',
#  'Acecook',
#  'Aces',
#  'Adabi',
#  'Ah Lai',
#  'Aji-no-men',
#  'Ajinatori',
#  'Ajinomoto',
#  'Alhami',
#  'Amianda',
#  'Amino',
#  "Annie Chun's",
#  'Ao Ba Ba',
#  'Aroi',
#  'Artisan',
#  'Asia Gold',
#  'Asian Thai Foods',
#  'Assi',
#  'Atomy',
#  'Authentically Asian',
#  'Azami',
#  'Baijia',
#  'Baixiang',
#  'Baixiang Noodles',
#  'Baltix',
#  'Baman',
#  'Bamee',
#  'Banzai',
#  'Batchelors',
#  'Being Blue',
#  'Best Wok',
#  'Big Bon',
#  'Binh Tay',
#  'Blount',
#  'Bon Go Jang',
#  'Bonasia',
#  'Boss',
#  'Bowlfull',
#  'Boys & Girls',
#  'Buitoni',
#  'Burung Layang Terbang',
#  'CJ CheilJedang',
#  'COCO 2.0',
#  "Campbell's",
#  'Canton',
#  'Cao Is Starving',
#  'Cap Atoom Bulan',
#  'CarJEN',
#  'Charming Couple',
#  "Chaudhary's Wai Wai",
#  'Cheetos',
#  "Chef Nic's Noodles",
#  'Chef Woo',
#  'Chencun',
#  'Chering Chang',
#  'Chewy',
#  'Chikara',
#  'Chil Kab Farm Products',
#  'Chillies Brand',
#  'China Best',
#  "Ching's Secret",
#  'Chitato',
#  'Chongqing Suanlabao Food Co., Ltd.',
#  'Chorip Dong',
#  'ChoripDong',
#  'Choumama',
#  'Chuan Wei Wang',
#  'Chuanbei',
#  'Cigala',
#  'Cintan',
#  'Conimex',
#  'Crystal Noodle',
#  "Culley's",
#  'Curry Prince',
#  'Da Long Yi',
#  'Daddy',
#  'Daifuku',
#  'Daikoku',
#  'Daisho',
#  'Dara/Ciptarasa',
#  'Daraz',
#  'Delling',
#  'Deshome',
#  'Doll',
#  'Dongwon',
#  'Doshirak',
#  'Double Mountain',
#  "Dr. McDougall's",
#  'Dragonfly',
#  'Dream Kitchen',
#  'Du Du',
#  'E-Zee',
#  'E-mi',
#  'EDO Pack',
#  'Easybab',
#  'Eat & Go',
#  'Ebisoba Ichigen',
#  'Econsave',
#  'Eight Field',
#  'Emart',
#  'FMF',
#  'Fairy Bridge',
#  "Fan's Kitchen",
#  'Fantastic',
#  'Fantastic Noodles',
#  "Farmer's Heart",
#  'Fashion Food',
#  'Fashion Foods',
#  'Fenweixiang',
#  'FitMee',
#  'Foodmon',
#  'Forest Noodles',
#  'Fortune',
#  'Four Seas',
#  'Fox',
#  'Fu Chang Chinese Noodle Company',
#  'Fu Chung',
#  'Fuji Mengyo',
#  'Fujiwara',
#  'Fuku',
#  'Fukumen',
#  'GB Company',
#  'GGE',
#  'GS25',
#  'GaGa',
#  'Gau Do',
#  'Gefen',
#  'Global Inspiration',
#  'Goku Uma',
#  'Goku-Uma',
#  'Golden Mie',
#  'Golden Wheat',
#  'Golden Wonder',
#  'Gomex',
#  'Good Tto Leu Foods',
#  'Gookmul',
#  'Great Value',
#  'GreeNoodle',
#  'Gu Sister',
#  'Guangyou',
#  'Guava Story',
#  'Gurimi',
#  'Haioreum',
#  'Hakubaku',
#  'Han',
#  "Han's South Korea",
#  'Hankow',
#  'Hao Way',
#  'Haogemen',
#  'Happy Cook',
#  'Happy Family',
#  'Happy Noodle',
#  'Healtimie',
#  'Helper',
#  'Hi Lai Foods',
#  'Hi-Lai Foods',
#  'Hi-Myon',
#  'Hide Chan',
#  'Higashi',
#  'Higashimaru',
#  'Hikari Miso',
#  'Himawari-Shokuhin',
#  'Hite',
#  'HoMyeonDang',
#  'Hokkaido Furano Ramen',
#  'Hokkaido Ramen Santouka',
#  'Hosoonyi',
#  'House Of Delicious Taste',
#  'Hsin Tung Yang',
#  'Hua Feng',
#  'Hua Feng Noodle Expert',
#  'ICA',
#  'IbuRamen',
#  'Ibumie',
#  'Ichiran',
#  'Ichiran Ramen',
#  'Igarashi Seifun',
#  'Igarashi Seimen',
#  'Ikeda Shoku',
#  'Indomie',
#  'Ishimaru',
#  'Island Foods',
#  'Isoyama Shoji',
#  'Itomen',
#  'Itsuki',
#  'J-Basket',
#  'J.J.',
#  'JAL',
#  'JFC',
#  'JML',
#  'Jackpot Teriyaki',
#  'Jinanbo',
#  'Jinbo Selection',
#  'Jingqi',
#  'Jinmailang',
#  'Jinya Ramen Bar',
#  'Jongga',
#  'Jub Jub',
#  'Just Way',
#  'KOKA',
#  'Kabuto Noodles',
#  'Kailo',
#  'Kailo Brand',
#  'Kamfen',
#  'KampongKu',
#  'Kang Shi Fu',
#  'Kaset',
#  'Katoz',
#  "Kay's",
#  'Kenko Foods',
#  'Kenmin',
#  'Kiki',
#  'Kiki Noodle',
#  'Kikusui',
#  'Kim & Kim',
#  'Kim Ve Wong',
#  "Kim's Bowl",
#  'Kimura',
#  'Kin-Dee',
#  'Kinchan',
#  'Kiseki Foods',
#  'Kizuki Ramen & Izakaya',
#  'Knorr',
#  'Ko-Lee',
#  'Koh Thai',
#  'Koka',
#  'Kolson',
#  'Komforte Chockolates',
#  'Kormosa',
#  'Kou Da Xiang',
#  'Koyo',
#  'Kubota',
#  'Kumamoto',
#  'Kung Fu Noodles',
#  'Kuriki',
#  'Kuro Tetsuya',
#  'LMF',
#  'La Fonte',
#  'La Moderna',
#  'Lau Liu Tou',
#  'Lau Liu tou',
#  'Lee Fah Mee',
#  'Lee Kum Kee',
#  'LeeZen',
#  'Lele',
#  'Lemonilo',
#  'Liang Cheng Mai',
#  'Liangchengmei',
#  'Liangshi Nara',
#  'Lien Ying',
#  'Liitle Couples',
#  'Lingzhu',
#  'Lipton',
#  'Lishan',
#  'Lishan Food Manufacturing',
#  'Little Cook',
#  'Little Couples',
#  'Little Couples Q Noodle',
#  'Little Q',
#  'Liu Quan',
#  'Long Jun Hang',
#  'Long Kow',
#  'LonoLife',
#  'Lotus Foods',
#  'Love Cook',
#  'Love To Share',
#  'Lucky Me!',
#  'Luosiking',
#  'MAMA',
#  'MIT',
#  'Maggi',
#  'Maison de Coree',
#  'Maitri',
#  'Mama',
#  "Mama Pat's",
#  'Mamee',
#  'Mamee / Shinsegae',
#  'Mamee Shinsegae',
#  'Mamee-Shinsegae',
#  'Maruchan',
#  'Marutai',
#  'Master Kong',
#  'Mazendo',
#  'Mee Jang',
#  'Meet Mee',
#  'Meimen',
#  'Men-Sunaoshi',
#  'Menraku',
#  'Mexi-Ramen',
#  'Mi E-Zee',
#  'Mi Sedaap',
#  'Miandom',
#  'Mibena',
#  'Micoem',
#  'Mie Sedaap',
#  'Migawon',
#  "Mike's Mighty Good Craft Ramen",
#  'Mikka',
#  'Miliket',
#  'Miracle Noodle',
#  'Mitoku',
#  'Mitukura',
#  'Mivina',
#  'Mo Xiao Xian',
#  "Mom's Dry Noodle",
#  'Morre',
#  'Mr. HOO',
#  "Mr. Lee's",
#  "Mr. Lee's Noodles",
#  'Mr. Meng',
#  'Mr. Min',
#  'Mr. Noodle',
#  'Mr. Noodles',
#  'Mr. Udon',
#  'Mug Shot',
#  'Mum Ngon',
#  'Muso',
#  'My Friend',
#  'MyKuali',
#  'MyOri',
#  'Mykuali',
#  'Myojo',
#  'Myramen',
#  'Nagao Noodle',
#  'Nagatanien',
#  'Nakaki',
#  'Nakaki Food',
#  'Nakaki Foods',
#  'Nakaya Shouten',
#  'Naked',
#  'Namchang',
#  'Nan Chuan Dao Sheng',
#  'Nan Hsing',
#  'Nan Jie Cun',
#  'Nanyang Chef',
#  'Nasoya',
#  'Neko',
#  'Neo~Essence',
#  'New Touch',
#  'New Way',
#  'Newgate Express',
#  'Nhu',
#  'Nishiyama Seimen',
#  'Nissin',
#  'Nissin ',
#  'Nissin Miojo',
#  'Nissin-Miojo',
#  'Niudafang',
#  'No Brand',
#  'No Name',
#  'Noah Foods',
#  'Nona Lim',
#  'Nongshim',
#  'Noodie',
#  'Noodle Time',
#  'Noodles Accompanied By Happiness',
#  'Nora Kitchen',
#  'Nyor Nyar',
#  'O Sung',
#  "O'Taste",
#  "O'taste",
#  'ORee Garden',
#  'Ogasawara',
#  'Ohsung',
#  'Omachi',
#  'One Culture Foods',
#  'One Dish Asia',
#  'Oni Hot Pot',
#  'Osaka Ramen',
#  'Ottogi',
#  'Oyatsu',
#  'PLN Food Co, Ltd.',
#  'Paldo',
#  'Paldo Vina',
#  'Palkin',
#  'Pama',
#  'Pamana',
#  'Pan Mee',
#  'Panco',
#  'Panda Signature',
#  'Pangdama',
#  'Papa',
#  'Patanjali',
#  'Payless',
#  'Ped Chef',
#  'Peyang',
#  'Peyoung',
#  'Picnic',
#  'Pirkka',
#  'Plats Du Chef',
#  'Pop Bihun',
#  'Pot Noodle',
#  'Pran',
#  'Premiere',
#  'President',
#  'President Rice',
#  'Prima',
#  'Prima Taste',
#  'Pringles',
#  'Pulmuone',
#  'Q',
#  'Qi Shi Liu Ren',
#  'Qicaiyuan',
#  'Qin Zong',
#  'Qinsheng',
#  'Quero',
#  'Quickchow',
#  'Ramen Express By Chef Woo',
#  'Ramen Hero',
#  'Rap Snacks',
#  'Red Chef',
#  'Rhee Bros Assi',
#  'Right Foods',
#  "Ripe'n'Dry",
#  'Rocket Brand',
#  'Roland',
#  'Rollton',
#  'Rooster',
#  'Royal Umbrella',
#  'Ruski',
#  'S&S',
#  'Sahmyook',
#  'Saigon Ve Wong',
#  'Saikebon',
#  "Sainsbury's",
#  'Saji',
#  'Sakura Noodle',
#  'Sakurai',
#  'Sakurai Foods',
#  'Salam Mie',
#  'Samlip',
#  'Samurai',
#  'Samurai Ramen',
#  'Samyang',
#  'Samyang Foods',
#  'San-Iku',
#  'Sanpo',
#  'Sanrio',
#  'Sanyang',
#  'Sanyo Foods',
#  'Sao Tao',
#  'Sapporo Ichiban',
#  'Sarimi',
#  'Sau Tao',
#  'Sawadee',
#  'Schylling',
#  'Sempio',
#  'Seven & I',
#  'Seven & i',
#  'Seven&I',
#  'Seven-Eleven',
#  'Shan',
#  'Shanjinshan',
#  'Shi Zu Ren',
#  'Shibu Ramen',
#  'Shin Horng',
#  'Shinsegae Mamee',
#  'Shirakiku',
#  'Shoo Loong Kan',
#  'Shuang Ren Hsu',
#  'Shun Savory',
#  'Sichuan Baijia',
#  'Sichuan Guangyou',
#  'Simply Asia',
#  'Singa-Me',
#  'Single Grain',
#  'Single High',
#  'Six Fortune',
#  'Smack',
#  'Snapdragon',
#  'Sokensha',
#  'Song Hak',
#  'Soup Daren',
#  'Soup De Pasta',
#  'Souper',
#  'Springlife',
#  'Star Anise Foods',
#  'Street Noodles',
#  'Sugakiya',
#  'Sugakiya Foods',
#  'Suimin',
#  'Sun Noodle',
#  'Sunaoshi',
#  'Sunfeast',
#  'Sunlee',
#  'Sunlight',
#  'Sunny Maid',
#  'Super',
#  'Super Bihun',
#  'Super God',
#  'SuperMi',
#  'Sura',
#  'Suraj',
#  'Sutah',
#  'Sutharos',
#  'TIEasy',
#  'TRDP',
#  'TTL',
#  'Tabate',
#  'TableMark',
#  'Tablemark',
#  'Taihodien',
#  'Taihodien Restaurant',
#  'Taim',
#  'Takamori',
#  'Takamori Kosan',
#  'Tao Kae Noi',
#  'Tapatio',
#  'Tasty Bite',
#  'Tasty ly',
#  'Tasty.ly',
#  'Tayho',
#  'Teishi',
#  'Ten-In',
#  'Teriyaki Time',
#  'Tesco',
#  'Thai Chef',
#  'Thai Choice',
#  'Thai Kitchen',
#  'Thai Pavilion',
#  'Thai Smile',
#  'Thai Town',
#  'The Bridge',
#  'The Kitchen Food',
#  'The Ramen Rater Select',
#  'Thien Houng Foods',
#  'Thien Huong Food',
#  'Three Meters',
#  'Three Meters Noodles',
#  'Tian Ling Ling',
#  'Tiger',
#  'Tiger Tiger',
#  'Toei',
#  'Tokachimen Koubou',
#  'Tokushima Seifun',
#  'Tokyo Noodle',
#  'Tokyo Ramen',
#  'Torishi',
#  "Trader Joe's",
#  'Tradition',
#  'Trident',
#  'Tropicana Slim',
#  'Tseng Noodle',
#  'Tseng Noodles',
#  'Tung-I',
#  'US Canning',
#  'Uncle Fun',
#  'Uncle Sun',
#  'Uni-President',
#  'Unif',
#  'Unif / Tung-I',
#  'Unif Tung-I',
#  'Unif-100',
#  'United',
#  'Unox',
#  'Unzen',
#  'Urban Noodle',
#  'Ve Wong',
#  'Vedan',
#  'Vi Huong',
#  'Vida Food Group',
#  'Vifon',
#  'Village Vanguard',
#  'Vina Acecook',
#  "Vit's",
#  'Vite Ramen',
#  'Wai Wai',
#  'Wang',
#  'Way Premium Foods',
#  'Weh Lih',
#  'Wei Chuan',
#  'Wei Lih',
#  'Wei Wei',
#  'Westbrae',
#  'Western Family',
#  'WhatIf? Foods',
#  'World O Noodle',
#  "World O' Noodle",
#  'Wu Mu',
#  'Wu-Mu',
#  'Wugudaochang',
#  'Xiao Ban Mian',
#  'Xiao Long Kan',
#  'Xiuhe',
#  'Yamachan',
#  'Yamadai',
#  'Yamamori',
#  'Yamamoto',
#  'Yamamoto Seifun',
#  'Yamasa',
#  'Yatekomo',
#  'Yeomradaewang',
#  'Yi Lai Shuen',
#  'Yibin',
#  'Yopokki',
#  'Young Poong',
#  'Yum Yum',
#  'Yum-Mie',
#  'Yumei',
#  'Zombear',
#  'Zow Zow',
#  'iMee',
#  'iNoodle',
#  'immi',
#  'nunu']

# %%
brand_names_map = {
    'A-Sha Dry Noodle':'A-Sha',
    'ABC President':'ABC',
    'Baixiang Noodles':'Baixiang',
    'ChoripDong':'Chorip Dong',
    'Fantastic Noodles':'Fantastic',
    'Fashion Foods':'Fashion Food',
    'Hua Feng Noodle Expert':'Hua Feng',
    'Ichiran Ramen':'Ichiran',
    'Lau Liu tou':'Lau Liu Tou',
    'Lishan Food Manufacturing':'Lishan',
    'Mr. Lee\'s Noodles':'Mr. Lee\'s',
    'Mr. Noodle':'Mr. Noodles',
    'Nakaki Foods':'Nakaki Food',
    'Nakaki':'Nakaki Food',
    'Nissin ':'Nissin',
    'Nissin Miojo':'Nissin',
    'Nissin-Miojo':'Nissin',
    "O'taste":'O\'Taste',
    "O\'Taste":'O\'Taste',
   'Sakurai Foods':'Sakurai',
    'Samurai Ramen':'Samurai',
    'Seven&I':'Seven & I',
    'Seven & i':'Seven & I',
    'Sugakiya Foods':'Sugakiya',
    'Tablemark':'TableMark',
    'Tasty ly':'Tasty.ly',
    'Thien Houng Foods':'Thien Houng Food',
    'Three Meters Noodles':'Three Meters',
    'Tseng Noodle':'Tseng Noodles',
    'Unif / Tung-I':'Unif',
    'Unif Tung-I':'Unif',
    'Unif-100':'Unif',
    'Yamamoto Seifun':'Yamamoto',
    'Weh Lih':'Wei Lih',
    'Wu Mu':'Wu-Mu',
    'World O Noodle':'World O\' Noodle'
}

df['Brand'] = df['Brand'].replace(brand_names_map)

unique_brands_sorted_renamed = sorted(df['Brand'].unique())
unique_brands_sorted_renamed
# Out:
# ['1 To 3 Noodles',
#  '7 Select',
#  '7 Select/Nissin',
#  '7-Eleven / Nissin',
#  'A-One',
#  'A-Sha',
#  'A1',
#  'ABC',
#  'Acecook',
#  'Aces',
#  'Adabi',
#  'Ah Lai',
#  'Aji-no-men',
#  'Ajinatori',
#  'Ajinomoto',
#  'Alhami',
#  'Amianda',
#  'Amino',
#  "Annie Chun's",
#  'Ao Ba Ba',
#  'Aroi',
#  'Artisan',
#  'Asia Gold',
#  'Asian Thai Foods',
#  'Assi',
#  'Atomy',
#  'Authentically Asian',
#  'Azami',
#  'Baijia',
#  'Baixiang',
#  'Baltix',
#  'Baman',
#  'Bamee',
#  'Banzai',
#  'Batchelors',
#  'Being Blue',
#  'Best Wok',
#  'Big Bon',
#  'Binh Tay',
#  'Blount',
#  'Bon Go Jang',
#  'Bonasia',
#  'Boss',
#  'Bowlfull',
#  'Boys & Girls',
#  'Buitoni',
#  'Burung Layang Terbang',
#  'CJ CheilJedang',
#  'COCO 2.0',
#  "Campbell's",
#  'Canton',
#  'Cao Is Starving',
#  'Cap Atoom Bulan',
#  'CarJEN',
#  'Charming Couple',
#  "Chaudhary's Wai Wai",
#  'Cheetos',
#  "Chef Nic's Noodles",
#  'Chef Woo',
#  'Chencun',
#  'Chering Chang',
#  'Chewy',
#  'Chikara',
#  'Chil Kab Farm Products',
#  'Chillies Brand',
#  'China Best',
#  "Ching's Secret",
#  'Chitato',
#  'Chongqing Suanlabao Food Co., Ltd.',
#  'Chorip Dong',
#  'Choumama',
#  'Chuan Wei Wang',
#  'Chuanbei',
#  'Cigala',
#  'Cintan',
#  'Conimex',
#  'Crystal Noodle',
#  "Culley's",
#  'Curry Prince',
#  'Da Long Yi',
#  'Daddy',
#  'Daifuku',
#  'Daikoku',
#  'Daisho',
#  'Dara/Ciptarasa',
#  'Daraz',
#  'Delling',
#  'Deshome',
#  'Doll',
#  'Dongwon',
#  'Doshirak',
#  'Double Mountain',
#  "Dr. McDougall's",
#  'Dragonfly',
#  'Dream Kitchen',
#  'Du Du',
#  'E-Zee',
#  'E-mi',
#  'EDO Pack',
#  'Easybab',
#  'Eat & Go',
#  'Ebisoba Ichigen',
#  'Econsave',
#  'Eight Field',
#  'Emart',
#  'FMF',
#  'Fairy Bridge',
#  "Fan's Kitchen",
#  'Fantastic',
#  "Farmer's Heart",
#  'Fashion Food',
#  'Fenweixiang',
#  'FitMee',
#  'Foodmon',
#  'Forest Noodles',
#  'Fortune',
#  'Four Seas',
#  'Fox',
#  'Fu Chang Chinese Noodle Company',
#  'Fu Chung',
#  'Fuji Mengyo',
#  'Fujiwara',
#  'Fuku',
#  'Fukumen',
#  'GB Company',
#  'GGE',
#  'GS25',
#  'GaGa',
#  'Gau Do',
#  'Gefen',
#  'Global Inspiration',
#  'Goku Uma',
#  'Goku-Uma',
#  'Golden Mie',
#  'Golden Wheat',
#  'Golden Wonder',
#  'Gomex',
#  'Good Tto Leu Foods',
#  'Gookmul',
#  'Great Value',
#  'GreeNoodle',
#  'Gu Sister',
#  'Guangyou',
#  'Guava Story',
#  'Gurimi',
#  'Haioreum',
#  'Hakubaku',
#  'Han',
#  "Han's South Korea",
#  'Hankow',
#  'Hao Way',
#  'Haogemen',
#  'Happy Cook',
#  'Happy Family',
#  'Happy Noodle',
#  'Healtimie',
#  'Helper',
#  'Hi Lai Foods',
#  'Hi-Lai Foods',
#  'Hi-Myon',
#  'Hide Chan',
#  'Higashi',
#  'Higashimaru',
#  'Hikari Miso',
#  'Himawari-Shokuhin',
#  'Hite',
#  'HoMyeonDang',
#  'Hokkaido Furano Ramen',
#  'Hokkaido Ramen Santouka',
#  'Hosoonyi',
#  'House Of Delicious Taste',
#  'Hsin Tung Yang',
#  'Hua Feng',
#  'ICA',
#  'IbuRamen',
#  'Ibumie',
#  'Ichiran',
#  'Igarashi Seifun',
#  'Igarashi Seimen',
#  'Ikeda Shoku',
#  'Indomie',
#  'Ishimaru',
#  'Island Foods',
#  'Isoyama Shoji',
#  'Itomen',
#  'Itsuki',
#  'J-Basket',
#  'J.J.',
#  'JAL',
#  'JFC',
#  'JML',
#  'Jackpot Teriyaki',
#  'Jinanbo',
#  'Jinbo Selection',
#  'Jingqi',
#  'Jinmailang',
#  'Jinya Ramen Bar',
#  'Jongga',
#  'Jub Jub',
#  'Just Way',
#  'KOKA',
#  'Kabuto Noodles',
#  'Kailo',
#  'Kailo Brand',
#  'Kamfen',
#  'KampongKu',
#  'Kang Shi Fu',
#  'Kaset',
#  'Katoz',
#  "Kay's",
#  'Kenko Foods',
#  'Kenmin',
#  'Kiki',
#  'Kiki Noodle',
#  'Kikusui',
#  'Kim & Kim',
#  'Kim Ve Wong',
#  "Kim's Bowl",
#  'Kimura',
#  'Kin-Dee',
#  'Kinchan',
#  'Kiseki Foods',
#  'Kizuki Ramen & Izakaya',
#  'Knorr',
#  'Ko-Lee',
#  'Koh Thai',
#  'Koka',
#  'Kolson',
#  'Komforte Chockolates',
#  'Kormosa',
#  'Kou Da Xiang',
#  'Koyo',
#  'Kubota',
#  'Kumamoto',
#  'Kung Fu Noodles',
#  'Kuriki',
#  'Kuro Tetsuya',
#  'LMF',
#  'La Fonte',
#  'La Moderna',
#  'Lau Liu Tou',
#  'Lee Fah Mee',
#  'Lee Kum Kee',
#  'LeeZen',
#  'Lele',
#  'Lemonilo',
#  'Liang Cheng Mai',
#  'Liangchengmei',
#  'Liangshi Nara',
#  'Lien Ying',
#  'Liitle Couples',
#  'Lingzhu',
#  'Lipton',
#  'Lishan',
#  'Little Cook',
#  'Little Couples',
#  'Little Couples Q Noodle',
#  'Little Q',
#  'Liu Quan',
#  'Long Jun Hang',
#  'Long Kow',
#  'LonoLife',
#  'Lotus Foods',
#  'Love Cook',
#  'Love To Share',
#  'Lucky Me!',
#  'Luosiking',
#  'MAMA',
#  'MIT',
#  'Maggi',
#  'Maison de Coree',
#  'Maitri',
#  'Mama',
#  "Mama Pat's",
#  'Mamee',
#  'Mamee / Shinsegae',
#  'Mamee Shinsegae',
#  'Mamee-Shinsegae',
#  'Maruchan',
#  'Marutai',
#  'Master Kong',
#  'Mazendo',
#  'Mee Jang',
#  'Meet Mee',
#  'Meimen',
#  'Men-Sunaoshi',
#  'Menraku',
#  'Mexi-Ramen',
#  'Mi E-Zee',
#  'Mi Sedaap',
#  'Miandom',
#  'Mibena',
#  'Micoem',
#  'Mie Sedaap',
#  'Migawon',
#  "Mike's Mighty Good Craft Ramen",
#  'Mikka',
#  'Miliket',
#  'Miracle Noodle',
#  'Mitoku',
#  'Mitukura',
#  'Mivina',
#  'Mo Xiao Xian',
#  "Mom's Dry Noodle",
#  'Morre',
#  'Mr. HOO',
#  "Mr. Lee's",
#  'Mr. Meng',
#  'Mr. Min',
#  'Mr. Noodles',
#  'Mr. Udon',
#  'Mug Shot',
#  'Mum Ngon',
#  'Muso',
#  'My Friend',
#  'MyKuali',
#  'MyOri',
#  'Mykuali',
#  'Myojo',
#  'Myramen',
#  'Nagao Noodle',
#  'Nagatanien',
#  'Nakaki Food',
#  'Nakaya Shouten',
#  'Naked',
#  'Namchang',
#  'Nan Chuan Dao Sheng',
#  'Nan Hsing',
#  'Nan Jie Cun',
#  'Nanyang Chef',
#  'Nasoya',
#  'Neko',
#  'Neo~Essence',
#  'New Touch',
#  'New Way',
#  'Newgate Express',
#  'Nhu',
#  'Nishiyama Seimen',
#  'Nissin',
#  'Niudafang',
#  'No Brand',
#  'No Name',
#  'Noah Foods',
#  'Nona Lim',
#  'Nongshim',
#  'Noodie',
#  'Noodle Time',
#  'Noodles Accompanied By Happiness',
#  'Nora Kitchen',
#  'Nyor Nyar',
#  'O Sung',
#  "O'Taste",
#  'ORee Garden',
#  'Ogasawara',
#  'Ohsung',
#  'Omachi',
#  'One Culture Foods',
#  'One Dish Asia',
#  'Oni Hot Pot',
#  'Osaka Ramen',
#  'Ottogi',
#  'Oyatsu',
#  'PLN Food Co, Ltd.',
#  'Paldo',
#  'Paldo Vina',
#  'Palkin',
#  'Pama',
#  'Pamana',
#  'Pan Mee',
#  'Panco',
#  'Panda Signature',
#  'Pangdama',
#  'Papa',
#  'Patanjali',
#  'Payless',
#  'Ped Chef',
#  'Peyang',
#  'Peyoung',
#  'Picnic',
#  'Pirkka',
#  'Plats Du Chef',
#  'Pop Bihun',
#  'Pot Noodle',
#  'Pran',
#  'Premiere',
#  'President',
#  'President Rice',
#  'Prima',
#  'Prima Taste',
#  'Pringles',
#  'Pulmuone',
#  'Q',
#  'Qi Shi Liu Ren',
#  'Qicaiyuan',
#  'Qin Zong',
#  'Qinsheng',
#  'Quero',
#  'Quickchow',
#  'Ramen Express By Chef Woo',
#  'Ramen Hero',
#  'Rap Snacks',
#  'Red Chef',
#  'Rhee Bros Assi',
#  'Right Foods',
#  "Ripe'n'Dry",
#  'Rocket Brand',
#  'Roland',
#  'Rollton',
#  'Rooster',
#  'Royal Umbrella',
#  'Ruski',
#  'S&S',
#  'Sahmyook',
#  'Saigon Ve Wong',
#  'Saikebon',
#  "Sainsbury's",
#  'Saji',
#  'Sakura Noodle',
#  'Sakurai',
#  'Salam Mie',
#  'Samlip',
#  'Samurai',
#  'Samyang',
#  'Samyang Foods',
#  'San-Iku',
#  'Sanpo',
#  'Sanrio',
#  'Sanyang',
#  'Sanyo Foods',
#  'Sao Tao',
#  'Sapporo Ichiban',
#  'Sarimi',
#  'Sau Tao',
#  'Sawadee',
#  'Schylling',
#  'Sempio',
#  'Seven & I',
#  'Seven-Eleven',
#  'Shan',
#  'Shanjinshan',
#  'Shi Zu Ren',
#  'Shibu Ramen',
#  'Shin Horng',
#  'Shinsegae Mamee',
#  'Shirakiku',
#  'Shoo Loong Kan',
#  'Shuang Ren Hsu',
#  'Shun Savory',
#  'Sichuan Baijia',
#  'Sichuan Guangyou',
#  'Simply Asia',
#  'Singa-Me',
#  'Single Grain',
#  'Single High',
#  'Six Fortune',
#  'Smack',
#  'Snapdragon',
#  'Sokensha',
#  'Song Hak',
#  'Soup Daren',
#  'Soup De Pasta',
#  'Souper',
#  'Springlife',
#  'Star Anise Foods',
#  'Street Noodles',
#  'Sugakiya',
#  'Suimin',
#  'Sun Noodle',
#  'Sunaoshi',
#  'Sunfeast',
#  'Sunlee',
#  'Sunlight',
#  'Sunny Maid',
#  'Super',
#  'Super Bihun',
#  'Super God',
#  'SuperMi',
#  'Sura',
#  'Suraj',
#  'Sutah',
#  'Sutharos',
#  'TIEasy',
#  'TRDP',
#  'TTL',
#  'Tabate',
#  'TableMark',
#  'Taihodien',
#  'Taihodien Restaurant',
#  'Taim',
#  'Takamori',
#  'Takamori Kosan',
#  'Tao Kae Noi',
#  'Tapatio',
#  'Tasty Bite',
#  'Tasty.ly',
#  'Tayho',
#  'Teishi',
#  'Ten-In',
#  'Teriyaki Time',
#  'Tesco',
#  'Thai Chef',
#  'Thai Choice',
#  'Thai Kitchen',
#  'Thai Pavilion',
#  'Thai Smile',
#  'Thai Town',
#  'The Bridge',
#  'The Kitchen Food',
#  'The Ramen Rater Select',
#  'Thien Houng Food',
#  'Thien Huong Food',
#  'Three Meters',
#  'Tian Ling Ling',
#  'Tiger',
#  'Tiger Tiger',
#  'Toei',
#  'Tokachimen Koubou',
#  'Tokushima Seifun',
#  'Tokyo Noodle',
#  'Tokyo Ramen',
#  'Torishi',
#  "Trader Joe's",
#  'Tradition',
#  'Trident',
#  'Tropicana Slim',
#  'Tseng Noodles',
#  'Tung-I',
#  'US Canning',
#  'Uncle Fun',
#  'Uncle Sun',
#  'Uni-President',
#  'Unif',
#  'United',
#  'Unox',
#  'Unzen',
#  'Urban Noodle',
#  'Ve Wong',
#  'Vedan',
#  'Vi Huong',
#  'Vida Food Group',
#  'Vifon',
#  'Village Vanguard',
#  'Vina Acecook',
#  "Vit's",
#  'Vite Ramen',
#  'Wai Wai',
#  'Wang',
#  'Way Premium Foods',
#  'Wei Chuan',
#  'Wei Lih',
#  'Wei Wei',
#  'Westbrae',
#  'Western Family',
#  'WhatIf? Foods',
#  "World O' Noodle",
#  'Wu-Mu',
#  'Wugudaochang',
#  'Xiao Ban Mian',
#  'Xiao Long Kan',
#  'Xiuhe',
#  'Yamachan',
#  'Yamadai',
#  'Yamamori',
#  'Yamamoto',
#  'Yamasa',
#  'Yatekomo',
#  'Yeomradaewang',
#  'Yi Lai Shuen',
#  'Yibin',
#  'Yopokki',
#  'Young Poong',
#  'Yum Yum',
#  'Yum-Mie',
#  'Yumei',
#  'Zombear',
#  'Zow Zow',
#  'iMee',
#  'iNoodle',
#  'immi',
#  'nunu']

# %%
country_avg = df.groupby('Country')['Stars'].mean().sort_values(ascending=False)
style_avg = df.groupby('Style')['Stars'].mean().sort_values(ascending=False)
brand_avg = df.groupby('Brand')['Stars'].mean().sort_values(ascending=False)

# %%
country_avg
# Out:
# Country
# France            4.333333
# Malaysia          4.201739
# Cambodia          4.200000
# Indonesia         4.122857
# Singapore         4.109375
# Spain             4.000000
# Myanmar           3.946429
# Taiwan            3.913457
# Hong Kong         3.880488
# South Korea       3.880140
# Japan             3.876568
# Fiji              3.875000
# Brazil            3.645833
# Hungary           3.611111
# Mexico            3.609375
# United States     3.587939
# Finland           3.583333
# Dubai             3.583333
# Ukraine           3.583333
# Russia            3.571429
# China             3.563112
# Germany           3.532895
# Nepal             3.517857
# Ghana             3.500000
# Estonia           3.500000
# Bangladesh        3.479167
# Thailand          3.475322
# India             3.456522
# Philippines       3.407407
# Peru              3.375000
# Colombia          3.291667
# Australia         3.260000
# Sweden            3.250000
# Vietnam           3.221318
# Pakistan          3.192308
# United Kingdom    3.116883
# Poland            3.083333
# New Zealand       3.000000
# Israel            3.000000
# Italy             2.750000
# Netherlands       2.712500
# Nigeria           2.375000
# Canada            2.330357
# Serbia            2.300000
# Portugal          2.000000
# Ireland           1.500000
# Name: Stars, dtype: float64

# %%
style_avg
# Out:
# Style
# Bar           5.000000
# Box           4.262821
# Bottle        4.000000
# Pack          3.811710
# Bowl          3.738708
# Restaurant    3.583333
# Tray          3.572115
# Can           3.500000
# Cup           3.493806
# Name: Stars, dtype: float64

# %%
brand_avg
# Out:
# Brand
# Baman              5.0
# Torishi            5.0
# Vida Food Group    5.0
# Tian Ling Ling     5.0
# Thai Town          5.0
#                   ...
# Kim Ve Wong        0.0
# Tiger              0.0
# One Dish Asia      0.0
# Dr. McDougall's    0.0
# Fairy Bridge       0.0
# Name: Stars, Length: 580, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=country_avg.index, y=country_avg.values)
plt.xticks(rotation=90)
plt.title('Avg Ramen Rating Country')
plt.xlabel('Country')
plt.ylabel('Average Rating')
plt.show()

# %%
country_review_counts = df['Country'].value_counts()
print('Number of review from France:', country_review_counts.get('France', 0))
# Out:
# Number of review from France: 6

# %%
france_review = df[df['Country'] == 'France']
print(france_review[['Brand', 'Variety', 'Stars']])
# Out:
#                Brand                                Variety  Stars
# 637          Mr. Min      Original Korean Ramen Beef Flavor   4.25
# 659          Mr. Min  Original Korean Ramen Instant Noodles   5.00
# 943  Maison de Coree                 Ramen Gout Coco Poulet   3.75
# 950  Maison de Coree                   Ramen Gout Carbonara   4.00
# 967  Maison de Coree                   Ramen Gout BBQ Coree   5.00
# 975  Maison de Coree                  Ramen Gout Poulet Feu   4.00

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Stars'], color='skyblue')
plt.title('Box Plot of Ramen Ratings')
plt.xlabel('Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Stars'], bins=20, edgecolor='black')
plt.title('Distrubution of Ramen Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
df['Stars'].describe()
# Out:
# count    4113.000000
# mean        3.734780
# std         1.043151
# min         0.000000
# 25%         3.250000
# 50%         3.750000
# 75%         4.500000
# max         5.000000
# Name: Stars, dtype: float64

# %%
brand_reivew_counts = df['Brand'].value_counts()
brand_reivew_counts
# Out:
# Brand
# Nissin             530
# Maruchan           149
# Myojo              133
# Nongshim           126
# Samyang Foods      103
#                   ...
# Namchang             1
# Igarashi Seifun      1
# Omachi               1
# Tung-I               1
# Westbrae             1
# Name: count, Length: 580, dtype: int64

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x=brand_reivew_counts.head(20).values, y=brand_reivew_counts.head(20).index, palette='viridis', legend=False, hue=brand_reivew_counts.head(20))
plt.title('Top 20 Most Review Ramen Brands')
plt.xlabel('Number of Reviews')
plt.ylabel('Brand')
plt.show()

# %%
brand_avg_ratings = df.groupby('Brand')['Stars'].mean()

brand_stats = pd.DataFrame({
    'Review_Counts': brand_reivew_counts,
    'Average_Ratin': brand_avg_ratings
})

print(brand_stats.sort_values(by='Review_Counts', ascending=False).head(10))
# Out:
#                  Review_Counts  Average_Ratin
# Brand
# Nissin                     530       3.879953
# Maruchan                   149       3.663591
# Myojo                      133       3.909774
# Nongshim                   126       4.039683
# Samyang Foods              103       4.097087
# Paldo                       87       4.043103
# Sapporo Ichiban             83       3.737952
# Mama                        71       3.628873
# Acecook                     62       3.133065
# Indomie                     60       4.016667

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Style', y='Stars', data=df)
plt.title('Distribution of Ramen Ratings by Style')
plt.xlabel('Ramen Style')
plt.ylabel('Rating')
plt.show()
